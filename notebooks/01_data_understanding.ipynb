# %% [markdown]
# # PCOS Health Analytics Platform
#
# ## Notebook 1: Data Understanding
#
# ### Objective
#
# Understand the structure, quality, and characteristics of the PCOS dataset before data cleaning and exploratory analysis.
#
# ### Dataset Used
#
# This notebook focuses on the **main PCOS clinical dataset** (`PCOS_data_without_infertility.xlsx`). The accompanying infertility dataset is included in the repository and will be explored separately later in the project to assess any additional or complementary clinical insights.

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option("display.max_columns", None)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Loading datasets
df_main = pd.read_excel(
    "../data/raw/PCOS_data_without_infertility.xlsx",
    sheet_name="Full_new"
)
df_infertility = pd.read_csv("../data/raw/PCOS_infertility.csv")

# %%
#Data preview
df_main.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#          BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  \
# 0  19.300000           15                78                22     10.48
# 1  24.921163           15                74                20     11.70
# 2  25.270891           11                72                18     11.80
# 3  29.674945           13                72                20     12.00
# 4  20.060954           11                72                18     10.00
#
# ...

# %% [markdown]
# ### Observation
#
# The dataset preview confirms that the data has been loaded successfully. It contains patient demographic information, clinical measurements, hormonal parameters, lifestyle factors, and ultrasound findings relevant to PCOS analysis.

# %%
df_infertility.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)    I   beta-HCG(mIU/mL)  \
# 0       1             10001           0                    1.99
# 1       2             10002           0                   60.80
# 2       3             10003           1                  494.08
# 3       4             10004           0                    1.99
# 4       5             10005           0                  801.45
#
#    II    beta-HCG(mIU/mL) AMH(ng/mL)
# 0                    1.99       2.07
# 1                    1.99       1.53
# 2                  494.08       6.63
# 3                    1.99       1.22
# 4                  801.45       2.26

# %%
#dataset shape
print("Main Dataset Shape:", df_main.shape)
print("Infertility Dataset Shape:", df_infertility.shape)
# Out:
# Main Dataset Shape: (541, 45)
# Infertility Dataset Shape: (541, 6)

# %% [markdown]
# ### Key Findings
#
# - The main dataset contains **541 rows** and **45 columns**.
# - The infertility dataset contains **541 rows** and **6 columns**.

# %%
#Dataset Information
df_main.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3    Age (yrs)              541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   BMI                     541 non-null    float64
#  7   Blood Group             541 non-null    int64
#  8   Pulse rate(bpm)         541 non-null    int64
#  9   RR (breaths/min)        541 non-null    int64
#  10  Hb(g/dl)                541 non-null    float64
#  11  Cycle(R/I)              541 non-null    int64
#  12  Cycle length(days)      541 non-null    int64
#  13  Marraige Status (Yrs)   540 non-null    float64
# ...

# %%
#Missing values
missing = df_main.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# Unnamed: 44              539
# Marraige Status (Yrs)      1
# Fast food (Y/N)            1
# dtype: int64

# %% [markdown]
# ### Missing Value Assessment
#
# The dataset contains very few missing values.
#
# - `Unnamed: 44` contains **539** missing values and appears to be an empty column introduced during Excel export.
# - `Marraige Status (Yrs)` contains **1** missing value.
# - `Fast food (Y/N)` contains **1** missing value.
#
# Overall, the dataset is highly complete, requiring minimal preprocessing before analysis.

# %%
#Duplicate records
df_main.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Observation
#
# No duplicate records were found in the dataset, indicating that each row represents a unique patient record.

# %%
#Summary statistics
df_main.describe()
# Out:
#            Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# count  541.000000        541.000000  541.000000  541.000000   541.000000
# mean   271.000000        271.000000    0.327172   31.430684    59.637153
# std    156.317519        156.317519    0.469615    5.411006    11.028287
# min      1.000000          1.000000    0.000000   20.000000    31.000000
# 25%    136.000000        136.000000    0.000000   28.000000    52.000000
# 50%    271.000000        271.000000    0.000000   31.000000    59.000000
# 75%    406.000000        406.000000    1.000000   35.000000    65.000000
# max    541.000000        541.000000    1.000000   48.000000   108.000000
#
#        Height(Cm)          BMI  Blood Group  Pulse rate(bpm)   \
# count   541.000000  541.000000   541.000000        541.000000
# mean    156.484835   24.311285    13.802218         73.247689
# std       6.033545    4.056399     1.840812          4.430285
# ...

# %% [markdown]
# ### Sumamry
#
# The summary statistics indicate that most clinical variables fall within expected ranges. However, some hormonal measurements (e.g., FSH, LH, Vitamin D, β-hCG) exhibit unusually high maximum values. These observations will be investigated further during exploratory data analysis to determine whether they represent valid clinical cases or potential outliers.

# %%
#Column names
df_main.columns.tolist()
# Out:
# ['Sl. No',
#  'Patient File No.',
#  'PCOS (Y/N)',
#  ' Age (yrs)',
#  'Weight (Kg)',
#  'Height(Cm) ',
#  'BMI',
#  'Blood Group',
#  'Pulse rate(bpm) ',
#  'RR (breaths/min)',
#  'Hb(g/dl)',
#  'Cycle(R/I)',
#  'Cycle length(days)',
#  'Marraige Status (Yrs)',
#  'Pregnant(Y/N)',
#  'No. of aborptions',
#  '  I   beta-HCG(mIU/mL)',
#  'II    beta-HCG(mIU/mL)',
#  'FSH(mIU/mL)',
#  'LH(mIU/mL)',
#  'FSH/LH',
#  'Hip(inch)',
#  'Waist(inch)',
#  'Waist:Hip Ratio',
#  'TSH (mIU/L)',
#  'AMH(ng/mL)',
#  'PRL(ng/mL)',
#  'Vit D3 (ng/mL)',
#  'PRG(ng/mL)',
#  'RBS(mg/dl)',
#  'Weight gain(Y/N)',
#  'hair growth(Y/N)',
#  'Skin darkening (Y/N)',
#  'Hair loss(Y/N)',
#  'Pimples(Y/N)',
#  'Fast food (Y/N)',
#  'Reg.Exercise(Y/N)',
#  'BP _Systolic (mmHg)',
#  'BP _Diastolic (mmHg)',
#  'Follicle No. (L)',
#  'Follicle No. (R)',
#  'Avg. F size (L) (mm)',
#  'Avg. F size (R) (mm)',
#  'Endometrium (mm)',
#  'Unnamed: 44']

# %% [markdown]
# ## Dataset Variables
#
# The variables in the dataset can be grouped into the following categories:
#
# ### Patient & Demographic Information
# - Patient File No.
# - Age
# - Blood Group
# - Marriage Status
#
# ### Anthropometric Measurements
# - Weight
# - Height
# - BMI
# - Waist Circumference
# - Hip Circumference
# - Waist-Hip Ratio
#
# ### Vital Signs
# - Pulse Rate
# - Respiratory Rate
# - Blood Pressure
# - Hemoglobin
#
# ### Reproductive & Menstrual History
# - Cycle Regularity
# - Cycle Length
# - Pregnancy Status
# - Number of Abortions
#
# ### Hormonal Parameters
# - FSH
# - LH
# - FSH/LH Ratio
# - TSH
# - PRL
# - AMH
# - β-hCG
# - Vitamin D3
# - Progesterone
#
# ### Lifestyle Factors
# - Fast Food
# - Regular Exercise
#
# ### Clinical Symptoms
# - Weight Gain
# - Hair Growth
# - Skin Darkening
# - Hair Loss
# - Pimples
#
# ### Ultrasound Findings
# - Follicle Count (Left & Right)
# - Average Follicle Size
# - Endometrium Thickness
#
# ### Target Variable
# - PCOS (Y/N)

# %% [markdown]
# ## Notebook Summary
#
# This notebook explored the structure and quality of the PCOS dataset prior to data preprocessing.
#
# ### Key Findings
#
# - The dataset contains **541 patient records** and **45 variables**.
# - No duplicate records were identified.
# - Only three columns contain missing values, indicating that the dataset is largely complete.
# - An additional unnamed column appears to be an empty Excel column and will be removed during preprocessing.
# - Several hormone-related variables contain unusually high values that require further investigation during exploratory analysis.
#
# The next notebook focuses on cleaning and preparing the dataset for analysis.
